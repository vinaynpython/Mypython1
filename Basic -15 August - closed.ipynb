# %% [markdown]
# # Python Basics
# ## Arithmatic Operations
# ___

# %%
a= 10; b=20 ; print(a+b) ; print(a-b) ; print(a*b); print(a/b) ; print(a%b); print(a>b); print(a<b); print(a==b);
# Out:
# 30
# -10
# 200
# 0.5
# 10
# False
# True
# False

# %% [markdown]
# ## Types of Data
# __ __
# ### Types of data are like Integer, Float, String, Boolean - Short form - Int, float, Str, Bool

# %%
c= 1.1 ; type(c) # Decimal values counts in float values
# Out:
# float

# %%
d=1 ; type(d)  # Regular values counts in Integer values
# Out:
# int

# %%
e=True ; type(e) # Boolean values are True and False where the results get in True and False
# Out:
# bool

# %%
f="Vinay"; type(f)  # String values can be called as Text values or values in "" , '' ,'''  '''
# Out:
# str

# %% [markdown]
# # Data Types - 1) Numbers
# ## Variables assigning or Data Storing to use it further

# %%
x,y,z = 1,2,3 ;  
g,h,i = 1.9,"a","vinay" ;
j=k=l= "last one" ; 
m = ["First", "Second", 3] ;

# %%
print(x); print(y); print(z) ; print(g); print(h); print(i) ; print(j) ; print(k); print(l); print(m)
# Out:
# 1
# 2
# 3
# 1.9
# a
# vinay
# last one
# last one
# last one
# ['First', 'Second', 3]

# %% [markdown]
# ## Handy helpful function for # list ##
# - del < To delete the values present in string or list
# - pop < To delte the last value present in list

# %%
m = ["First", "Second", 3] ;  # in list the position start as 0,1,2,3,4 -
del m[0] ;                           #  here at 0 its value is "First" and so on
print(m)                            # here we deleteout value present on 0 position
# Out:
# ['Second', 3]

# %%
m.pop() ; print (m) # Pop is used to delete the specific value present in list 
    # If you do not define value in bracket it pops out last value present in list
# Out:
# ['Second']

# %%
m.extend("1"); print(m) # Extend only takes one value in list
# Out:
# ['Second', '1', '1', '1', '1']

# %%
m.append("One"); print(m) # Append also adds the value and even takes one value
# Out:
# ['Second', '1', '1', '1', '1', 'One', 'One', 'One']

# %%
m.count('1') # Count function use to count the number characters which has repeated in list
# Out:
# 4

# %%
m.clear();  print(m) ; # Flush out all the values assigned to a variable
# Out:
# []

# %% [markdown]
# The syntax of the insert() method is
#
# list.insert(i, elem)
# Here, elem is inserted to the list at the ith index. All the elements after elem are shifted to the right.

# %%
m.insert(0,"1") ; m.insert(2,"3")

# %%
print(m)
# Out:
# ['1', '3']

# %%
m.insert(2,"4") ; m.insert(3,"2"); print(m)
# Out:
# ['1', '3', '4', '2', '4']

# %%
m.index('3')  
# Index function provide the position of value in list
# Out:
# 1

# %%
m.remove('4'); print(m)
# Out:
# ['1', '3', '2', '4']

# %%
m.sort(); print(m)
# Out:
# ['1', '2', '3', '4']

# %% [markdown]
# Sort function helps to sort data as per alphabets or numeric values by default whereas remove function helps to delete the specific value defind in the bracket.

# %%
m.reverse(); print(m) #Reverse all the value position- last number comes at 0 position
# Out:
# ['4', '3', '2', '1']

# %% [markdown]
# #### Between some Arithmatic and If & Else functions use

# %%
if z>y : 
    print("3 is greater than 2") 
else: 
    print("Change the value")
# Complex functions show
#Example 1
if (x+y==3) :
    print("Correct")
else:
    print("Wrong")
#Example 2
# Use of BODMAS (Bracket,of,Division, Multiplication, Addition, Substraction)

if (x-y*x+y/x>=2) :
    print("Correct")
# 1-2*1+2/1 -1+2 = "1"    Lesser than 2
else:
    print("Wrong")
    
#Example 3
# Out:
# 3 is greater than 2
# Correct
# Wrong

# %% [markdown]
# ## Standard Data types information

# %% [markdown]
# __
#
# *Standard Data Types*
# *The data stored in memory can be of many types. For example, a person's age is stored as a numeric value and his or her address is stored as alphanumeric characters. Python has various standard data types that are used to define the operations possible on them and the storage method for each of them.*
#
# Python has five standard data types −
#
# 1. Numbers (Variable assigning which is do
# 2. String
# 3. List
# 4. Tuple
# 5. Dictionary
# ____

# %% [markdown]
# # 2. String data type ## Functions of *str

# %%
my_string = "I am Vinay" ; type(my_string)
# Out:
# str

# %%
my_string.capitalize() # this function capitalise the first word and rewrite the sentence 
                       # according
# Out:
# 'I am vinay'

# %%
my_string.casefold()
# Out:
# 'i am vinay'

# %%
my_string.
# Out:
#   File "<ipython-input-206-38ca27aee311>", line 1
#     my_string.
#               ^
# SyntaxError: invalid syntax

# %%
list.
